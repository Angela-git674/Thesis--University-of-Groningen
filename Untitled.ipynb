# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 3
#       1 import numpy as np # linear algebra
#       2 import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# ----> 3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
#       5 import os
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
pip install numpy
# Out:
# Collecting numpy
#   Downloading numpy-2.2.0-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Downloading numpy-2.2.0-cp313-cp313-win_amd64.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.6 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.6 MB 844.3 kB/s eta 0:00:15
#    -- ------------------------------------- 0.8/12.6 MB 1.1 MB/s eta 0:00:11
#    --- ------------------------------------ 1.0/12.6 MB 1.1 MB/s eta 0:00:11
#    ---- ----------------------------------- 1.3/12.6 MB 1.2 MB/s eta 0:00:10
#    ----- ---------------------------------- 1.8/12.6 MB 1.3 MB/s eta 0:00:09
#    -------- ------------------------------- 2.6/12.6 MB 1.7 MB/s eta 0:00:06
#    ---------- ----------------------------- 3.4/12.6 MB 2.0 MB/s eta 0:00:05
#    ------------- -------------------------- 4.2/12.6 MB 2.2 MB/s eta 0:00:04
#    --------------- ------------------------ 5.0/12.6 MB 2.3 MB/s eta 0:00:04
#    ------------------ --------------------- 5.8/12.6 MB 2.5 MB/s eta 0:00:03
#    --------------------- ------------------ 6.8/12.6 MB 2.7 MB/s eta 0:00:03
#    ------------------------- -------------- 8.1/12.6 MB 2.9 MB/s eta 0:00:02
#    ----------------------------- ---------- 9.2/12.6 MB 3.1 MB/s eta 0:00:02
#    -------------------------------- ------- 10.2/12.6 MB 3.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.3/12.6 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------  12.3/12.6 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 3.4 MB/s eta 0:00:00
# Installing collected packages: numpy
# Successfully installed numpy-2.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.2.3-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\angelikiloulo\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\angelikiloulo\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\angelikiloulo\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.2.3-cp313-cp313-win_amd64.whl (11.5 MB)
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.5 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.5 MB 1.6 MB/s eta 0:00:08
#    -- ------------------------------------- 0.8/11.5 MB 1.5 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.3/11.5 MB 1.6 MB/s eta 0:00:07
#    ------ --------------------------------- 1.8/11.5 MB 1.9 MB/s eta 0:00:06
#    --------- ------------------------------ 2.6/11.5 MB 2.2 MB/s eta 0:00:05
#    ----------- ---------------------------- 3.4/11.5 MB 2.4 MB/s eta 0:00:04
#    -------------- ------------------------- 4.2/11.5 MB 2.6 MB/s eta 0:00:03
#    ----------------- ---------------------- 5.0/11.5 MB 2.8 MB/s eta 0:00:03
#    --------------------- ------------------ 6.0/11.5 MB 3.0 MB/s eta 0:00:02
#    ------------------------ --------------- 7.1/11.5 MB 3.2 MB/s eta 0:00:02
#    ---------------------------- ----------- 8.1/11.5 MB 3.3 MB/s eta 0:00:02
#    ------------------------------- -------- 9.2/11.5 MB 3.5 MB/s eta 0:00:01
#    ------------------------------------ --- 10.5/11.5 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 3.8 MB/s eta 0:00:00
# Downloading pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Downloading tzdata-2024.2-py2.py3-none-any.whl (346 kB)
# Installing collected packages: pytz, tzdata, pandas
# Successfully installed pandas-2.2.3 pytz-2024.2 tzdata-2024.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np  # Linear algebra
import pandas as pd  # Data processing, CSV file I/O
import matplotlib.pyplot as plt  # Plotting
import seaborn as sns  # Statistical visualization
import os  # File and directory operations
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 import numpy as np  # Linear algebra
#       2 import pandas as pd  # Data processing, CSV file I/O
#       3 import matplotlib.pyplot as plt  # Plotting
#
# ModuleNotFoundError: No module named 'numpy'

# %%
import numpy as np  # Linear algebra
import pandas as pd  # Data processing, CSV file I/O

# %%
import pandas as pd

# Load the dataset from the uploaded file
file_path = ''
dataset = pd.read_csv(file_path)

# Display the first few rows of the dataset to confirm successful loading
dataset.head()
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\m'
# <>:4: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\AngelikiLoulo\AppData\Local\Temp\ipykernel_4520\4157154333.py:4: SyntaxWarning: invalid escape sequence '\m'
#   file_path = '\mnt\data\imdb_movies_cleaned_filtered_with_star_actors.csv'
# C:\Users\AngelikiLoulo\AppData\Local\Temp\ipykernel_4520\4157154333.py:4: SyntaxWarning: invalid escape sequence '\m'
#   file_path = '\mnt\data\imdb_movies_cleaned_filtered_with_star_actors.csv'
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 5
#       3 # Load the dataset from the uploaded file
#       4 file_path = '\mnt\data\imdb_movies_cleaned_filtered_with_star_actors.csv'
# ----> 5 dataset = pd.read_csv(file_path)
#       7 # Display the first few rows of the dataset to confirm successful loading
#       8 dataset.head()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '\\mnt\\data\\imdb_movies_cleaned_filtered_with_star_actors.csv'

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 3
#       1 import numpy as np # linear algebra
#       2 import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# ----> 3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
#       5 import os
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 3
#       1 import numpy as np # linear algebra
#       2 import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# ----> 3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
#       5 import os
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# Import the necessary library
import pandas as pd

# Define the file path
file_path = 'imdb_movies_cleaned_filtered_with_star_actors.csv'

# Load the dataset
dataset = pd.read_csv(file_path)

# Display the first few rows
dataset.head(2345)
# Out:
#                                      names      date_x  score  \
# 0                                creed iii    3/2/2023     73
# 1                 avatar: the way of water  12/15/2022     78
# 2              the super mario bros. movie    4/5/2023     76
# 3                                  mummies    1/5/2023     70
# 4                                supercell   3/17/2023     61
# ...                                    ...         ...    ...
# 2340                       the survivalist   10/1/2021     40
# 2341             puff: wonders of the reef   10/1/2021     77
# 2342                     birds of paradise   9/24/2021     67
# 2343      shark beach with chris hemsworth    7/9/2021     63
# 2344  conversations in front of the camera    4/6/2023      0
#
#                                               genre  \
# 0                                     Drama, Action
# 1                Science Fiction, Adventure, Action
# 2     Animation, Adventure, Family, Fantasy, Comedy
# 3     Animation, Comedy, Family, Adventure, Fantasy
# 4                                            Action
# ...                                             ...
# 2340              Action, Science Fiction, Thriller
# 2341                                    Documentary
# 2342                                          Drama
# 2343                                    Documentary
# 2344                                 Drama, Romance
#
#                                                overview  \
# 0     After dominating the boxing world, Adonis Cree...
# 1     Set more than a decade after the events of the...
# 2     While working underground to fix a water main,...
# 3     Through a series of unfortunate events, three ...
# 4     Good-hearted teenager William always lived in ...
# ...                                                 ...
# 2340  A year and a half after the fall of civilizati...
# 2341  A baby pufferfish travels through a wondrous m...
# 2342  Two dancers at an elite ballet academy in Pari...
# 2343  Chris Hemsworth has a real passion for sharks....
# 2344  The main character Andrei was abandoned by a g...
#
#                                                    crew  \
# 0     Michael B. Jordan, Adonis Creed, Tessa Thompso...
# 1     Sam Worthington, Jake Sully, Zoe Saldaña, Neyt...
# 2     Chris Pratt, Mario (voice), Anya Taylor-Joy, P...
# 3     Óscar Barberán, Thut (voice), Ana Esther Albor...
# 4     Skeet Ulrich, Roy Cameron, Anne Heche, Dr Quin...
# ...                                                 ...
# 2340  Jonathan Rhys Meyers, Ben, John Malkovich, Aar...
# 2341                       Rose Byrne, Narrator (voice)
# 2342  Diana Silvers, Kate Sanders, Kristine Froseth,...
# 2343  Chris Hemsworth, Self, Valerie Taylor, Self, M...
# 2344                                Dima Markov, Andrey
#
#                             orig_title           orig_lang     budget_x  \
# 0                            Creed III             English   75000000.0
# 1             Avatar: The Way of Water             English  460000000.0
# 2          The Super Mario Bros. Movie             English  100000000.0
# 3                               Momias  Spanish, Castilian   12300000.0
# 4                            Supercell             English   77000000.0
# ...                                ...                 ...          ...
# 2340                   The Survivalist             English  101800000.0
# 2341         Puff: Wonders of the Reef             English   62100000.0
# 2342                 Birds of Paradise             English   75500000.0
# 2343  Shark Beach With Chris Hemsworth             English   90000000.0
# 2344           Разговоры перед камерой             Russian  185534545.8
#
#            revenue country  season event_week budget_ranges  sequels  \
# 0     2.716167e+08      AU  Spring        NaN    Mid Budget        0
# 1     2.316795e+09      AU  Winter        NaN    Big Budget        0
# 2     7.244590e+08      AU  Spring        NaN    Mid Budget        0
# 3     3.420000e+07      AU  Winter        NaN    Low Budget        0
# 4     3.409420e+08      US  Spring        NaN    Mid Budget        0
# ...            ...     ...     ...        ...           ...      ...
# 2340  8.586376e+08      US  Autumn        NaN    Mid Budget        0
# 2341  5.345186e+08      US  Autumn        NaN    Mid Budget        0
# 2342  5.097261e+08      US  Autumn        NaN    Mid Budget        0
# 2343  4.330796e+08      AU  Summer        NaN    Mid Budget        0
# 2344  1.783599e+08      RU  Spring        NaN    Big Budget        0
#
#       star_actor
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 2340           1
# 2341           0
# 2342           0
# 2343           1
# 2344           0
#
# [2345 rows x 16 columns]
